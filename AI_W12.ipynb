# %% [markdown]
# <a href="https://colab.research.google.com/github/Chinhan1532/AI_Class/blob/main/AI_W12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename='/content/images.jpg'
img=plt.imread(filename)
plt.imshow(img)

# %%
detector = MTCNN()
faces = detector.detect_faces(img)
for face in faces:
  print(face)
# Out:
# ...
# 3/3 [==============================] - 1s 67ms/step
# {'box': [147, 13, 16, 23], 'confidence': 0.9999200701713562, 'keypoints': {'left_eye': (151, 23), 'right_eye': (159, 23), 'nose': (155, 29), 'mouth_left': (151, 32), 'mouth_right': (159, 32)}}
# {'box': [192, 187, 14, 18], 'confidence': 0.9994403123855591, 'keypoints': {'left_eye': (196, 193), 'right_eye': (203, 193), 'nose': (199, 197), 'mouth_left': (196, 201), 'mouth_right': (203, 201)}}
# {'box': [190, 99, 15, 20], 'confidence': 0.9992260336875916, 'keypoints': {'left_eye': (193, 107), 'right_eye': (201, 107), 'nose': (197, 111), 'mouth_left': (194, 114), 'mouth_right': (202, 113)}}
# {'box': [60, 12, 14, 18], 'confidence': 0.9991934895515442, 'keypoints': {'left_eye': (64, 19), 'right_eye': (71, 18), 'nose': (67, 23), 'mouth_left': (64, 25), 'mouth_right': (71, 25)}}
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename='/content/real.jpg'
img=plt.imread(filename)
plt.imshow(img)

# %%
detector = MTCNN()
faces = detector.detect_faces(img)
for face in faces:
  print(face)
# Out:
# ...
# 5/5 [==============================] - 0s 32ms/step
# {'box': [615, 18, 33, 41], 'confidence': 0.999999463558197, 'keypoints': {'left_eye': (622, 33), 'right_eye': (637, 32), 'nose': (629, 41), 'mouth_left': (623, 50), 'mouth_right': (636, 49)}}
# {'box': [423, 126, 36, 46], 'confidence': 0.9999601244926453, 'keypoints': {'left_eye': (431, 143), 'right_eye': (448, 143), 'nose': (440, 152), 'mouth_left': (431, 158), 'mouth_right': (450, 157)}}
# {'box': [177, 13, 32, 42], 'confidence': 0.9999557137489319, 'keypoints': {'left_eye': (186, 27), 'right_eye': (201, 29), 'nose': (193, 35), 'mouth_left': (186, 44), 'mouth_right': (198, 45)}}
# {'box': [349, 11, 31, 42], 'confidence': 0.9999315142631531, 'keypoints': {'left_eye': (355, 27), 'right_eye': (369, 27), 'nose': (360, 34), 'mouth_left': (355, 43), 'mouth_right': (368, 43)}}
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename='/content/ars.jpg'
img=plt.imread(filename)
plt.imshow(img)

# %%
detector = MTCNN()
faces = detector.detect_faces(img)
for face in faces:
  print(face)
# Out:
# 1/1 [==============================] - 1s 692ms/step
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd84bce48b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# 9/9 [==============================] - 1s 63ms/step
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import savefig
from mtcnn import MTCNN
filename='/content/real.jpg'
img=plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax=plt.gca()
for face in faces:
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
  for key,value in face['keypoints'].items():
    dot=plt.Circle(value,radius=2,color='red')
    ax.add_patch(dot)
  savefig('/content/drive/MyDrive/AIclass/real')
plt.show()
# Out:
# ...
# 5/5 [==============================] - 0s 34ms/step

# %%
filename='/content/drive/MyDrive/AIclass/real.png'
img= plt.imread(filename)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
def draw_faces(filename,result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height=result_list[i]['box']
    x2,y2 = x1+width, y1+height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
  plt.show()
filename='/content/real.jpg'
img=plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(img)
draw_faces(filename,faces)
savefig('/content/drive/MyDrive/AIclass/realmadrid/anh')
# Out:
# ...
# 5/5 [==============================] - 1s 60ms/step

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/lacda.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted: [('n02437312', 'Arabian_camel', 0.9999826), ('n02437616', 'llama', 7.1679883e-06), ('n02093991', 'Irish_terrier', 4.4445296e-06)]

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np


model = VGG16(weights='imagenet', include_top=True)

img_path = '/content/noicom.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print('Predicted:', decode_predictions(features, top=3)[0])
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted: [('n03908714', 'pencil_sharpener', 0.98113304), ('n02747177', 'ashcan', 0.0043091555), ('n04442312', 'toaster', 0.0024188636)]

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.models import Model
import numpy as np


base_model = VGG19(weights='imagenet', include_top=True)
model = Model(inputs=base_model.input, outputs=base_model.get_layer('block4_pool').output)

img_path = '/content/daibang.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

block4_pool_features = model.predict(x)
# Out:
# 1/1 [==============================] - 1s 732ms/step
