# %% [markdown]
# <a href="https://colab.research.google.com/github/Chinhan1532/BT-AI/blob/main/AI_W3_T2_07_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 CREATE A DATAFRAME

# %%
# load library
import pandas as pd
# create dataframe
dataframe = pd.DataFrame()
# add columns
dataframe['Name'] = ['Lemon','Apple','Banana']
dataframe['Price'] = [5,8,7]
dataframe['License'] = [False, True, True]
# show data
dataframe
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
dataframe.shape
# Out:
# (3, 3)

# %%
df = dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Price    3 non-null      int64
#  2   License  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
list(df.columns)
# Out:
# ['Name', 'Price', 'License']

# %%
df.describe()
#std: do lech chuan
# Out:
#           Price
# count  3.000000
# mean   6.666667
# std    1.527525
# min    5.000000
# 25%    6.000000
# 50%    7.000000
# 75%    7.500000
# max    8.000000

# %%
df.loc[(df.Price == 5)]
# Out:
#     Name  Price  License
# 0  Lemon      5    False

# %%
df.loc[(df.Price == 8)| (df.Name == 'Banana')]
# df.price == 8 : goi ra cac hang co gia tri = 8
# df.Name = 'Banana' : goi ra cac hang co ten Banana
# Out:
#      Name  Price  License
# 1   Apple      8     True
# 2  Banana      7     True

# %%
df.loc[(df.Price ==5)|(df.Name == 'Banana'), ['Name','Price']]
# chi xuat ra cot Name vaf Price
# Out:
#      Name  Price
# 0   Lemon      5
# 2  Banana      7

# %%
df.iloc[2]
type(df.iloc[2])
# Out:
# pandas.core.series.Series

# %%
df.iloc[[2]]
#Tri xuat den hang thu 2 cua bang du lieu
# Out:
#      Name  Price  License
# 2  Banana      7     True

# %%
df.iloc[0:2,0:-1]
#[0:2]: Lay ra cac gia tri tu 0 den 1 & [0:-1]: Bo cot cuoi cung
# Out:
#     Name  Price
# 0  Lemon      5
# 1  Apple      8

# %%
sum = df.Price.sum()
print(sum)
# Out:
# 20

# %%
count = df['Price'].count()
print(count)
# Out:
# 3

# %%
#create row data
new = pd.Series(['Orange',10,True], index=['Name', 'Price', 'License'])
# append row
dataframe.append(new, ignore_index=True)
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True
# 3  Orange     10     True

# %%
# Them 1 cot vao bang 
dataframe['Location']=['USA','VN','SIN']
dataframe
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 1   Apple      8     True       VN
# 2  Banana      7     True      SIN

# %%
# Xoa 1 hang
df.drop(1, axis=0).head()
#head(): xuat ra 5 gia tri | head(10): xuat ra 10 gia tri
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 2  Banana      7     True      SIN

# %%
# Xoa 1 cot
df.drop('Location', axis = 1). head()
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
# Replace 
# Thay so  5 bang so 7
df['Price'].replace(5,7).head(5)
# Out:
# 0    7
# 1    8
# 2    7
# Name: Price, dtype: int64

# %%
# Rename columns
df.rename(columns={'Price':'Cost'}).head()
# Out:
#      Name  Cost  License Location
# 0   Lemon     5    False      USA
# 1   Apple     8     True       VN
# 2  Banana     7     True      SIN

# %%
#2 KNOWING DATA

# %%
# load library
import pandas as pd
# create url
url = 'medals.csv'
# load data
dataframe = pd.read_csv(url)
# show data
dataframe.head(10)
# Out:
#    Year      City       Sport      Discipline  NOC            Event  \
# 0  1924  Chamonix     Skating  Figure skating  AUT       individual
# 1  1924  Chamonix     Skating  Figure skating  AUT       individual
# 2  1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 5  1924  Chamonix    Biathlon        Biathlon  FIN  military patrol
# 6  1924  Chamonix     Skating  Figure skating  FIN            pairs
# 7  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 8  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9  1924  Chamonix     Skating   Speed skating  FIN            1500m
#
#   Event gender   Medal
# 0            M  Silver
# 1            W    Gold
# 2            X    Gold
# 3            M  Bronze
# 4            M    Gold
# 5            M  Silver
# 6            X  Silver
# 7            M    Gold
# ...

# %%
data = dataframe
data.shape
# Out:
# (2311, 8)

# %%
list(data.columns)
# Out:
# ['Year',
#  'City',
#  'Sport',
#  'Discipline',
#  'NOC',
#  'Event',
#  'Event gender',
#  'Medal']

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# ...

# %%
data.loc[(data.Medal == 'Gold')&(data.NOC == 'FIN')]
# Out:
#       Year                    City    Sport       Discipline  NOC  \
# 7     1924                Chamonix  Skating    Speed skating  FIN
# 9     1924                Chamonix  Skating    Speed skating  FIN
# 10    1924                Chamonix  Skating    Speed skating  FIN
# 14    1924                Chamonix  Skating    Speed skating  FIN
# 55    1928              St. Moritz  Skating    Speed skating  FIN
# 58    1928              St. Moritz  Skating    Speed skating  FIN
# 100   1932             Lake Placid   Skiing  Cross Country S  FIN
# 142   1936  Garmisch-Partenkirchen   Skiing  Cross Country S  FIN
# 200   1948              St. Moritz   Skiing  Nordic Combined  FIN
# 262   1952                    Oslo   Skiing  Cross Country S  FIN
# 266   1952                    Oslo   Skiing  Cross Country S  FIN
# 267   1952                    Oslo   Skiing  Cross Country S  FIN
# 335   1956       Cortina d'Ampezzo   Skiing  Cross Country S  FIN
# ...

# %%
data.loc[(data.NOC=='JPN')]
# Out:
#       Year               City    Sport       Discipline  NOC  \
# 345   1956  Cortina d'Ampezzo   Skiing    Alpine Skiing  JPN
# 719   1972            Sapporo   Skiing      Ski Jumping  JPN
# 720   1972            Sapporo   Skiing      Ski Jumping  JPN
# 721   1972            Sapporo   Skiing      Ski Jumping  JPN
# 948   1980        Lake Placid   Skiing      Ski Jumping  JPN
# 1063  1984           Sarajevo  Skating    Speed skating  JPN
# 1190  1988            Calgary  Skating    Speed skating  JPN
# 1377  1992        Albertville  Skating   Figure skating  JPN
# 1378  1992        Albertville  Skating   Short Track S.  JPN
# 1379  1992        Albertville  Skating    Speed skating  JPN
# 1380  1992        Albertville  Skating    Speed skating  JPN
# 1381  1992        Albertville  Skating    Speed skating  JPN
# 1382  1992        Albertville  Skating    Speed skating  JPN
# 1383  1992        Albertville   Skiing  Nordic Combined  JPN
# ...

# %%
data.iloc[[1503]]
# Out:
#       Year         City Sport Discipline  NOC    Event Event gender Medal
# 1503  1994  Lillehammer  Luge       Luge  ITA  doubles            X  Gold

# %%
sum = data.Year.sum()
print(sum)
# Out:
# 4576616

# %%
data['NOC'].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
data['NOC'].unique()
# Out:
# array(['AUT', 'BEL', 'CAN', 'FIN', 'FRA', 'GBR', 'NOR', 'SUI', 'SWE',
#        'USA', 'GER', 'TCH', 'HUN', 'ITA', 'FRG', 'NED', 'EUA', 'JPN',
#        'POL', 'URS', 'PRK', 'GDR', 'ROU', 'ESP', 'LIE', 'BUL', 'YUG',
#        'CHN', 'EUN', 'KOR', 'LUX', 'NZL', 'AUS', 'BLR', 'KAZ', 'RUS',
#        'SLO', 'UKR', 'UZB', 'CZE', 'DEN', 'CRO', 'EST', 'LAT', 'SVK'],
#       dtype=object)

# %%
data.drop('NOC',axis = 1).head()
# Out:
#    Year      City       Sport      Discipline       Event Event gender   Medal
# 0  1924  Chamonix     Skating  Figure skating  individual            M  Silver
# 1  1924  Chamonix     Skating  Figure skating  individual            W    Gold
# 2  1924  Chamonix     Skating  Figure skating       pairs            X    Gold
# 3  1924  Chamonix   Bobsleigh       Bobsleigh    four-man            M  Bronze
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  ice hockey            M    Gold

# %%
#Sap xep theo bang chu cai
data = pd.read_csv(url)
data.groupby('NOC').head()
# Out:
#       Year      City       Sport       Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating   Figure skating  AUT       individual
# 1     1924  Chamonix     Skating   Figure skating  AUT       individual
# 2     1924  Chamonix     Skating   Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh        Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey       Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...              ...  ...              ...
# 2129  2006     Turin      Skiing  Cross Country S  EST             15km
# 2202  2006     Turin        Luge             Luge  LAT          singles
# 2269  2006     Turin      Skiing        Snowboard  SVK  Snowboard Cross
# 2284  2006     Turin    Biathlon         Biathlon  UKR            7.5km
# 2285  2006     Turin     Skating   Figure skating  UKR      ice dancing
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# ...

# %%
data.groupby(['Year','NOC']).head()
# Out:
#       Year      City       Sport      Discipline  NOC        Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT   individual
# 1     1924  Chamonix     Skating  Figure skating  AUT   individual
# 2     1924  Chamonix     Skating  Figure skating  AUT        pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL     four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN   ice hockey
# ...    ...       ...         ...             ...  ...          ...
# 2286  2006     Turin   Bobsleigh       Bobsleigh  USA      two-man
# 2287  2006     Turin     Curling         Curling  USA      curling
# 2288  2006     Turin  Ice Hockey      Ice Hockey  USA   ice hockey
# 2289  2006     Turin     Skating  Figure skating  USA  ice dancing
# 2290  2006     Turin     Skating  Figure skating  USA   individual
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# 3               M  Bronze
# ...

# %%
#Viet in hoa cot event
def uppercase(x):
  return x.upper()
data['Event'].apply(uppercase)[0:2311]
# Out:
# 0            INDIVIDUAL
# 1            INDIVIDUAL
# 2                 PAIRS
# 3              FOUR-MAN
# 4            ICE HOCKEY
#              ...
# 2306          HALF-PIPE
# 2307          HALF-PIPE
# 2308          HALF-PIPE
# 2309    SNOWBOARD CROSS
# 2310    SNOWBOARD CROSS
# Name: Event, Length: 2311, dtype: object

# %%
data.groupby(['Year','NOC']).count()
# Out:
#           City  Sport  Discipline  Event  Event gender  Medal
# Year NOC
# 1924 AUT     3      3           3      3             3      3
#      BEL     1      1           1      1             1      1
#      CAN     1      1           1      1             1      1
#      FIN    11     11          11     11            11     11
#      FRA     3      3           3      3             3      3
# ...        ...    ...         ...    ...           ...    ...
# 2006 SUI    14     14          14     14            14     14
#      SVK     1      1           1      1             1      1
#      SWE    14     14          14     14            14     14
#      UKR     2      2           2      2             2      2
#      USA    25     25          25     25            25     25
#
# [328 rows x 6 columns]

# %%
data[(data['Year']>=1990)&(data['Year']<=2006) & (data['NOC']=='USA')&(data['Event gender']=='W')&(data['Medal']=='Gold')].head(10)
# Out:
#       Year         City       Sport      Discipline  NOC       Event  \
# 1428  1992  Albertville     Skating  Figure skating  USA  individual
# 1430  1992  Albertville     Skating  Short Track S.  USA        500m
# 1431  1992  Albertville     Skating   Speed skating  USA       1000m
# 1432  1992  Albertville     Skating   Speed skating  USA        500m
# 1436  1992  Albertville      Skiing  Freestyle Ski.  USA      moguls
# 1610  1994  Lillehammer     Skating  Short Track S.  USA        500m
# 1612  1994  Lillehammer     Skating   Speed skating  USA       1000m
# 1613  1994  Lillehammer     Skating   Speed skating  USA        500m
# 1617  1994  Lillehammer      Skiing   Alpine Skiing  USA     super-G
# 1812  1998       Nagano  Ice Hockey      Ice Hockey  USA  ice hockey
#
#      Event gender Medal
# 1428            W  Gold
# 1430            W  Gold
# 1431            W  Gold
# 1432            W  Gold
# 1436            W  Gold
# 1610            W  Gold
# 1612            W  Gold
# ...

# %%
data = data.set_index(data['NOC'])
data.loc['GER']
# Out:
#      Year                    City       Sport       Discipline  NOC  \
# NOC
# GER  1928              St. Moritz   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid  Ice Hockey       Ice Hockey  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# ..    ...                     ...         ...              ...  ...
# GER  2006                   Turin      Skiing  Cross Country S  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing        Snowboard  GER
#
#                      Event Event gender   Medal
# NOC
# GER               five-man            M  Bronze
# ...

# %%
#Tri xuat ra cac gia tri ngoai tru CAN
data[data['NOC']!='CAN'].head(10)
# Out:
#      Year      City      Sport      Discipline  NOC            Event  \
# NOC
# AUT  1924  Chamonix    Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix    Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix    Skating  Figure skating  AUT            pairs
# BEL  1924  Chamonix  Bobsleigh       Bobsleigh  BEL         four-man
# FIN  1924  Chamonix   Biathlon        Biathlon  FIN  military patrol
# FIN  1924  Chamonix    Skating  Figure skating  FIN            pairs
# FIN  1924  Chamonix    Skating   Speed skating  FIN           10000m
# FIN  1924  Chamonix    Skating   Speed skating  FIN           10000m
# FIN  1924  Chamonix    Skating   Speed skating  FIN            1500m
# FIN  1924  Chamonix    Skating   Speed skating  FIN            5000m
#
#     Event gender   Medal
# NOC
# AUT            M  Silver
# AUT            W    Gold
# AUT            X    Gold
# BEL            M  Bronze
# FIN            M  Silver
# FIN            X  Silver
# ...
